# %% [markdown]
# # Funciones de orden superior y anónimas
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## Funciones de orden superior

# %% [markdown]
# Son funciones que cumplen al menos una de estas condiciones:
#
# * Reciben funciones como argumento
# * Devuelven funciones como resultado

# %% [markdown]
# * Reciben funciones como argumento

# %%
def suma(x, y):
    return x + y

# %%
def multiplicar(x, y):
    return x * y

# %%
def aplicar_operacion(func, a, b):
    resultado = func(a, b)
    return resultado

# %%
result = aplicar_operacion(suma, 2, 3)
result

# %%
result = aplicar_operacion(multiplicar, 2, 3)
result

# %%
suma

# %%
suma(5,5)

# %%
foo = suma

# %%
foo

# %%
foo(5, 7)

# %%
type(foo)

# %% [markdown]
# * Devuelven funciones como resultado

# %%
# se crea una funcion adentro de una funcion
def crear_multiplicador(n):

    def multiplicador(x):
        return x * n

    return multiplicador

# %%
por_dos = crear_multiplicador(2)

# %%
por_dos(5)

# %%
por_tres = crear_multiplicador(3)

# %%
por_tres(6)

# %% [markdown]
# Decoradores

# %%
from time import sleep

def hace_algo(x):

    sleep(x)
    return x + 1

# %%
hace_algo(5)

# %%
from functools import lru_cache
from time import sleep

@lru_cache()
def hace_algo(x):

    sleep(x)
    return x + 1

# %%
hace_algo(10)

# %%
hace_algo(10)

# %%
type(lru_cache)

# %% [markdown]
# Ejercicios

# %%
# Hacer una funcion, que toma una lista como parametro y
# retorna el menos valor

def menor_lista(lista):
    minimo = lista[0]

    for valor in lista:
      if minimo > valor:
        minimo = valor

    return minimo


numeros = [0, 5, 6, 8]
menor_lista(numeros)    # 0

# %% [markdown]
# Hacer una funcion que tome un string o una frase como parametro
# y retorne el caracter que mas veces aparece y cuantas veces aparecio
#
#
# ```python
# def max_caracter(frase: str):
#   pass
#
#
# max_caracter("holaaa")    # me deberia retorna la a con 3 apariciones
# ```

# %%
def max_caracter(texto: str) -> tuple[str, int]:
    if not texto:
        return "", 0

    frecuencias = {}

    for caracter in texto:
        frecuencias[caracter] = frecuencias.get(caracter, 0) + 1

    # Buscar el máximo
    caracter_max = max(frecuencias, key=frecuencias.get)
    return caracter_max, frecuencias[caracter_max]

# %%
max_caracter("holaaa")

# %% [markdown]
# Hacer una funcion que calcule el valor de positividad de un texto
#
# ```python
# def positividad(texto: str):
#   pass
#
#
# diccionario_positividad = {
#   "si": 10,
#   "no": -5,
#   "feliz": 8,
#   "triste": 2
# }
# ```
#
# Hay que ir tomando palabra por palabra del texto, ver el valor de positividad de esa palabra en el diccionario, ir acumulando la suma y al final calcular el promedio.
#
# las palabras que no estan en el diccionario tienen como valor de positividad 0
#
# ```python
# positividad = acumulado / cantidad de palabras
# ```

# %%
diccionario_positividad = {
  "si": 10,
  "no": -5,
  "feliz": 8,
  "triste": 2
}

# %%
def positividad(texto: str) -> float:
    if not texto:
        return 0.0

    palabras = texto.split()

    suma = 0
    cantidad = 0

    for palabra in palabras:
      suma += diccionario_positividad.get(palabra, 0)

    cantidad = len(palabras)

    return suma / cantidad

# %%
positividad("si no feliz triste casa")

# %% [markdown]
# Construir una función que se llame “promedio_variable”.
# Esta función debe tomar un número arbitrario de
# argumentos numéricos y devolver el promedio.

# %%
def suma(a, b):
  return a + b

# %%
def promedio_variable(*args):


  acumulado = 0

  for num in args:
    acumulado += num

  print("suma total: ", acumulado)

  cantidad = len(args)

  promedio = acumulado / cantidad

  return promedio

# %%
promedio_variable(1,2,3)

# %%
promedio_variable(4,4,4,4,4)

# %%
# docstring: ayuda de la funcion
def promedio_variable(*args):
  """
  Funcion que recibe una cantidad arbitraria de numeros enteros
  y retorna el promedio de esos numeros
  """

  acumulado = 0

  for num in args:
    acumulado += num

  print("suma total: ", acumulado)

  cantidad = len(args)

  promedio = acumulado / cantidad

  return promedio

# %%
help(promedio_variable)

# %%
promedio_variable()

# %% [markdown]
# Cree una función llamada “superior”, que reciba por
# argumento una función y una lista. La función que se
# pasa por argumento a superior debe elevar al cubo un
# número y retornarlo. Para que luego al aplicarla en la
# de orden superior, esa operación se realice miembro
# a miembro de la lista.
# Para finalizar la función “superior” debe de devolver
# una nueva lista.

# %%
def cubo(x):
  return x ** 3

# %%
def cuadrado(x):
  return x ** 2

# %%
def superior(func, lista):
  lista_cubo = []

  for valor in lista:
    cubo = func(valor)
    lista_cubo.append(cubo)

  return lista_cubo

# %%
numeros = [1,2,3]

# %%
superior(cubo, numeros)

# %%
superior(cuadrado, numeros)

# %% [markdown]
# ## Funciones anónimas (lambdas)

# %% [markdown]
# Las funciones lambda en Python son funciones anónimas, es decir, funciones sin nombre que se definen en una sola línea usando la palabra clave __lambda__.

# %%
potenciacion_dos = lambda x: x ** 2

# %%
potenciacion_dos(4)

# %%
type(potenciacion_dos)

# %%
sumar = lambda a, b: a + b

# %%
resta = lambda x, y: y - x

# %%
sumar(2, 3)

# %%
resta(5, 10)

# %%
"pedro".upper()

# %%
# Dada una lista de nombres, crear una nueva lista
# con los str en mayusculas

nombres = ["juan", "ana", "pedro"]
# nombre = ["JUAN", "ANA", "PEDRO"]
mayusculas = []

for nombre in nombres:
  nombre_mayuscula = nombre.upper()
  mayusculas.append(nombre_mayuscula)
  # mayusculas.append(nombre.upper())

print(mayusculas)

# %%
str.upper("juan")

# %%
# map(funcion, iterable)
nombres = ["juan", "ana", "pedro"]

mayusculas = map(str.upper, nombres)
mayusculas = list(mayusculas)

print(mayusculas)

# %%
# otro ejemplo con map
# dara una lista de numeros -- elevar al cuadrado
lista = [1, 2, 3, 4, 5]

cuadrados = map(lambda x: x ** 2, lista)

cuadrados = list(cuadrados)
cuadrados

# %% [markdown]
# Cuando usar:
#
# * La función es muy corta
# * Se usa una sola vez

# %% [markdown]
# ## Laboratorio

# %% [markdown]
# # Excepciones
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# Incluso si la sentencia o expresión es sintácticamente correcta, puede generar un error cuando se intenta ejecutarla. __Los errores detectados durante la ejecución se llaman excepciones__, y no son incondicionalmente fatales: pronto aprenderás cómo manejarlos en los programas en Python.

# %%
10/5

# %%
20/4

# %%
# Division por 0

resultado = 10 / 0
print("resultado: ", resultado)

# %%
lista = [0,1,2,3]
lista.pop()

# %%
lista.pop()

# %%
lista.pop()

# %%
# Extraer de una lista vacia

lista_valores = []

lista_valores.pop()

# %%
numero = float("45.8")
numero

# %%
type(numero)

# %%
# convertir un str no numerico a float

float("as")

# %%
"Hola"[0]

# %%
# Acceder a un indice inexistente

palabra = "Hola"

palabra[12]

# %%
frase = "Hola"

indice = int(input("Ingrese el indice: "))

frase[indice]

# %% [markdown]
# Como podemos suponer, es difícil prevenir fallos que ni siquiera nos habíamos planteado que podían existir. Por suerte para esas situaciones existen las excepciones.

# %% [markdown]
# Las excepciones son **bloques de código que nos permiten continuar con la ejecución de un programa pese a que ocurra un error**.

# %% [markdown]
# #### **try-except**

# %% [markdown]
# Para prevenir el fallo debemos poner el código propenso a errores en un bloque try y luego encadenar un bloque except para tratar la situación excepcional mostrando que ha ocurrido un fallo:
#
# ```
# try:
#   Bloque de codigo
# except:
#   Bloque de codigo
# ```

# %% [markdown]
# Funcionamiento:
#
# * Se ejecuta el bloque try (el código entre las sentencias try y except).
# * Si no ocurre ninguna excepción, el bloque except se saltea y termina la ejecución de la sentencia try.
# * Si ocurre una excepción durante la ejecución del bloque try, el resto del bloque se saltea. Luego, si su tipo coincide con la excepción nombrada luego de la palabra reservada except, se ejecuta el bloque except, y la ejecución continúa luego de la sentencia try.

# %%
# Sin manejo de Excepciones

numero1 = 10
numero2 = 0

print(f"Vamos a dividir {numero1} por {numero2}")

resultado = numero1 / numero2
print(f"resultado : {resultado}")

print("Continua el programa....")

# %%
# con manejo de excepciones
numero1 = 10
numero2 = 10

print(f"Vamos a dividir {numero1} por {numero2}")

try:
  print("Dentro del try")
  resultado = numero1 / numero2
  print(f"resultado : {resultado}")
except:
  print("No es posible dividir por 0")

print("Continua el programa....")

# %%
# con manejo de excepciones
numero1 = 10
numero2 = 0

print(f"Vamos a dividir {numero1} por {numero2}")

try:
  print("Dentro del try")
  resultado = numero1 / numero2
  print(f"resultado : {resultado}")
except:
  print("No es posible dividir por 0")

print("Continua el programa....")

# %%
# Capturando una excepcion especifica

numero1 = 10
numero2 = 10
print(f"Vamos a dividir {numero1} por {numero2}")

try:
  print("Dentro del try")
  resultado = numero1 / numero2
  print(f"resultado : {resultado}")
except ZeroDivisionError:
  print("No es posible dividir por 0")

print("Continua el programa....")

# %%
# Capturando una excepcion especifica

numero1 = 10
numero2 = 0
print(f"Vamos a dividir {numero1} por {numero2}")

try:
  print("Dentro del try")
  resultado = numero1 / numero2
  print(f"resultado : {resultado}")
except ZeroDivisionError:
  print("No es posible dividir por 0")

print("Continua el programa....")

# %% [markdown]
# Que pasa si ocurre otra Excepcion distinta a ZeroDivisionError?

# %%
numero1 = "10"
numero2 = 10
print(f"Vamos a dividir {numero1} por {numero2}")

try:
  print("Dentro del try")
  resultado = numero1 / numero2
  print(f"resultado : {resultado}")
except ZeroDivisionError:
  print("No es posible dividir por 0")

print("Continua el programa....")

# %%
# Que pasa si ocurre otra Excepcion distinta a ZeroDivisionError?

numero1 = 10
numero2 = "0"
print(f"Vamos a dividir {numero1} por {numero2}")

try:
  numero1 = int(numero1)
  numero2 = int(numero2)
  print("Dentro del try")
  resultado = numero1 / numero2
  print(f"resultado : {resultado}")
except ZeroDivisionError:
  print("No es posible dividir por 0")
except ValueError:
  print("No es posible convertir a entero")

print("Continua el programa....")

# %%
# ValueError

try:
  numero = int("A")
except ValueError:
  print("Error al convertir en entero!")

# %%
lista = [1, 2, 3, 4, 5]

# %%
# IndexError
try:
  foo = lista[30]
  print("foo", foo)
except IndexError:
  print(f"No es posible acceder a ese indice, la lista tiene: {len(lista)}")

# %%
# TypeError

lista = [1, 2, 3, 4, 5]

try:
  foo = lista[[0,1]]
except TypeError:
  print("No es posible acceder a ese indice")

# %%
lista = [1,2,3]

# %%
lista.pop()

# %%
lista = [1,2,3]

# %%
try:
  print(lista.pop())
except IndexError:
  print("La lista esta vacia")

# %%
lista = [1,2,3]

# %%
while len(lista) > 0:
  print(lista.pop())

# %%
while lista:
  print(lista.pop())

# %%
lista = [1,2,3]

# %%
for i in range(len(lista)):
  print(lista.pop())

# %%
lista = [1,2,3]

# %%
for _ in range(len(lista)):
  print(lista.pop())

# %% [markdown]
# Preguntas❓

# %% [markdown]
# #### **try-except-else**

# %% [markdown]
# Las declaraciones **try - except** tienen un bloque **else opcional**, el cual, cuando está presente, debe seguir a los except.
#
# **El uso de else es mejor que agregar código adicional en el try** porque evita capturar accidentalmente una excepción que no fue generada por el código que está protegido por la sentencia try - except.

# %%
#Ejemplo try - except - else

numero1 = 10
numero2 = 10

try:
    resultado = numero1 / numero2
except ZeroDivisionError:
    print("No se puede dividir por 0!")
else:
    print(f"resultado : {resultado}")

print("Continua el programa ...")

# %% [markdown]
# #### **finaly**

# %% [markdown]
# La sentencia try tiene otra sentencia **opcional** que intenta definir acciones de limpieza que deben ser ejecutadas bajo ciertas circunstancias. Una sentencia finaly **siempre es ejecutada antes de salir de la sentencia try, ya sea que una excepción haya ocurrido o no**.

# %% [markdown]
# Cuando ocurre una excepción en la sentencia try y no fue manejada por una sentencia except (u ocurrió en una sentencia except o else), es relanzada luego de que se ejecuta la sentencia finally.

# %%
# Ejemplo finaly

try:
  a = float(input("Introduce un número: "))
  b = float(input("Introduce otro número: "))
  print(a + b)
except:
    print("Ha ocurrido un error. Tienes que introducir 2 números.")
else:
    print("La suma se ha realizado correctamente.")
finally:
  # Esto se ejecuta siempre.
  print("Fin del bucle")

print("continua el programa!")

# %% [markdown]
# Preguntas❓

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### **Excepciones múltiples**

# %% [markdown]
# En una misma pieza de código pueden ocurrir muchos errores distintos y quizá nos interese actuar de forma diferente en cada caso.
#
# **Para esas situaciones algo que podemos hacer es asignar una excepción a una variable**.

# %%
try:
  numero1 = int(input("Introduce un número: "))
  numero2 = int(input("Introduce un número: "))
  resultado = numero1 ** 2
  resultado /= numero2
  print(resultado)
except Exception as e:
  # logging.error("Ha ocurrido un error =>", type(e).__name__)
  # exit(1)
  print("Ha ocurrido un error =>", type(e).__name__)

# %% [markdown]
# Cada error tiene un identificador único que curiosamente se corresponde con su tipo de dato. Aprovechando eso podemos mostrar la clase del error utilizando la sintaxis:
#
# ```
# print(type(e))
# ```

# %%
try:
  "Hola"[23]
except Exception as e:
  print(type(e))

# %%
try:
  lista= [0, 1, 2]
  lista[[0,1]]
except Exception as e:
  print(type(e))

# %% [markdown]
# Gracias a los identificadores de errores podemos crear múltiples comprobaciones, siempre que dejemos en último lugar la excepción por defecto. Excepción que engloba cualquier tipo de error.

# %%
try:
  numero = float(input("Introduce un número divisor: "))
  resultado = 5/numero
  print(resultado)

except TypeError:
  print("No se puede dividir el número entre una cadena")

except ValueError:
  print("Debes introducir una cadena que sea un número")

except ZeroDivisionError:
  print("No se puede dividir por cero, prueba otro número")

except Exception as e:
  print("Ha ocurrido un error no previsto", type(e).__name__ )

# %%
try:
  numero = float(input("Introduce un número divisor: "))
  resultado = 5/numero
  print(resultado)

except (TypeError, ValueError, ZeroDivisionError):
  print("Ocurrio un error")

except Exception as e:
  print("Ha ocurrido un error no previsto", type(e).__name__ )

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### **Lanzando excepciones**

# %% [markdown]
# En Python, la palabra clave **raise** se utiliza para generar (lanzar) una excepción de manera explícita. Puedes utilizar raise para indicar que ha ocurrido un error o una condición excepcional en tu código.

# %%
raise Exception("Ocurrio un error")

# %%
def division(numero1, numero2):

  if numero2 == 0:
    raise ValueError("El divisor tiene que ser mayor a 0")

  return numero1 / numero2

# %%
division(16,4)

# %%
division(5,0)

# %%
try:
  division(5,0)
except ValueError:
  print("No es posible dividir por 0")

# %% [markdown]
# Preguntas❓

# %% [markdown]
# # Operaciones sobre cadenas
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %%
# métodos soaciados a los str
# ningun método modifica el str original
# retornan un nuevo str
dir(str)

# %%
# nueva linea - \n
frase = "hola mundo\nme llamo juan"
print(frase)

# %%
# tabulacion - \t
print("hola\tmundo\t!!!!")

# %%
# acceso por indice
frase[0]

# %%
# no es posible modificarse
frase[0] = "H" # error

# %%
# concatenar str
"hola" + " " + "mundo!!!"

# %%
# split
"hola mundo me llamo juan".split()

# %%
"hola mundo-me-llamo-juan".split("-")

# %%
# unir una lista
" ".join(['hola', 'mundo', 'me', 'llamo', 'juan'])

# %%
"*".join(['hola', 'mundo', 'me', 'llamo', 'juan'])

# %%
"hola mundo".upper()

# %%
"hola mundo".capitalize()

# %%
"hola_mundo_me_llamo_juan".replace("_", " ")

# %%
help(str.lower)

# %% [markdown]
# # Entrada y salida de archivos
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# vscode

# %% [markdown]
# # Modulos y paquetes primera parte
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# Un módulo es un archivo de Python cuyos
# objetos (funciones, clases, variables,
# constantes, etc.) pueden ser accedidos desde
# otro archivo. Mientras que un paquete es una
# carpeta que contiene varios módulos.
# Python incluye una inmensa cantidad de
# módulos y paquetes nativamente

# %%
# Built-in no es necesario importar
len([1,4])

# %%
import math

# %%
math.pi

# %%
math.sqrt(25)

# %%
import random

# %%
numero = random.randint(1, 10)
print("Número aleatorio:", numero)

# %%
from datetime import datetime, timedelta

# %%
# con solo import datetime
# ahora = datetime.datetime.now()
ahora = datetime.now()
print("Fecha y hora actual:", ahora)

mañana = ahora + timedelta(days=2)
print("Mañana:", mañana)

# %%
import os

# %%
directorio_actual = os.getcwd()
print("Directorio actual:", directorio_actual)

archivos = os.listdir(directorio_actual)
print("Archivos:", archivos)

# %%
# !pwd

# %%
# !ls -lart
